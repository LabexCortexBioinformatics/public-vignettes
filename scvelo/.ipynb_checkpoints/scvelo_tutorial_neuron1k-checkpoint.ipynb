# %% [markdown]
# # Using scvelo to recover and analyze RNA velocity
# More info on the official [scvelo documentation](https://scvelo.readthedocs.io/about.html).

# %% [markdown]
# ### Installation
# To install scvelo, run the command `pip install -U scvelo`

# %% [markdown]
# ### Packages
# First step is to import all the needed packages. `copy` is not mandatory, and may in fact never be used, but can be useful if you don't want to modify the base data when creating a new object from an existing one.

# %%
! conda activate r-scvelo
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
import scvelo as scv
import pandas as pd
import copy
import pickle
import os
import csv
import anndata
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9f4a900d6139> in <module>
# ----> 1 import scvelo as scv
#       2 import pandas as pd
#       3 import copy
#       4 import pickle
#       5 import os
#
# ~/.local/lib/python3.8/site-packages/scvelo/__init__.py in <module>
#       1 """scvelo - RNA velocity generalized through dynamical modeling"""
#       2 from anndata import AnnData
# ----> 3 from scanpy import read, read_loom
#       4
#       5 from scvelo import datasets, logging, pl, pp, settings, tl, utils
#
# ~/.local/lib/python3.8/site-packages/scanpy/__init__.py in <module>
#       4
#       5 if not within_flit():  # see function docstring on why this is there
# ----> 6     from ._utils import check_versions
#       7
#       8     check_versions()
#
# ~/.local/lib/python3.8/site-packages/scanpy/_utils/__init__.py in <module>
# ...

# %% [markdown]
# After importing scvelo, you can verify the version.

# %%
scv.logging.print_version()
# Out:
# Running scvelo 0.2.4 (python 3.9.4) on 2021-09-08 13:08.

# %% [markdown]
# ## Load the Data
# There are several ways to load the data. Here we will show two of them, the first one using a `.loom` file from velocyto and the metadata from Seurat in `.csv`, and the second one using the **spliced** and **unspliced** assays from a Seurat object in csv.
#
# We decided to keep the information from the Seurat object (UMAP and metadata). We do not generate it from scvelo.
#
# ### From loom file
# Read the velocyto loom file and add Seurat umap and meta data.

# %%
# export Seurat object information from Rstudio
library(Seurat)
setwd('/mnt/Data1/Raineteau/2020_03_10X_dSVZ_p12_Nx_Hx/NxHx')

HxNx <- readRDS('Hx2Nx2_aggr_filtered_Nx2_Hx2_SdSelectionCells.rds')

write.csv(x = HxNx@meta.data, file = 'HxNx_meta.csv')
write.csv(x = HxNx@reductions$umap@cell.embeddings, file = 'HxNx_umap.csv')
# Out:
#   File "<ipython-input-3-c95fa66f64a0>", line 8
#     write.csv(x = HxNx@reductions$umap@cell.embeddings, file = 'HxNx_umap.csv')
#                                  ^
# SyntaxError: invalid syntax

# %%
# change working directory
os.chdir('/mnt/Data1/Raineteau/2020_03_10X_dSVZ_p12_Nx_Hx/NxHx')

# read loom file from velocyto
adata1 = scv.read_loom(filename='/mnt/Data1/Raineteau/2020_03_10X_dSVZ_p12_Nx_Hx/cellranger_count/Hx2/velocyto/Hx2.loom')
adata1.var_names_make_unique()
adata2 = scv.read_loom(filename='/mnt/Data1/Raineteau/2020_03_10X_dSVZ_p12_Nx_Hx/cellranger_count/Nx2/velocyto/Nx2.loom')
adata2.var_names_make_unique()

def rename_barcode(barcodes, trim_start, trim_end, add_start):
    """
    :param barcodes: list of barcodes to rename
    :param trim_start: characters to remove at the beginning of each barcode
    :param trim_end: characters to remove at the end of each barcode
    :return: the list of barcodes without the starting and ending characters
    """
    if trim_start != barcodes[0][0:len(trim_start)]:
        raise ValueError('trim_start not in cells')
    if trim_end != barcodes[0][-len(trim_end):]:
        raise ValueError('trim_end not in cells')
    return [add_start + i[len(trim_start): -len(trim_end)] for i in barcodes]

# use it to rename anndata cells
adata1.obs_names = rename_barcode(list(adata1.obs_names), "Hx2:", "x", "Hx2_")
adata2.obs_names = rename_barcode(list(adata2.obs_names), "Nx2:", "x", "NxCLB2_")

adata = anndata.concat((adata1, adata2))
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# read umap coordinates
X_umap = scv.load('HxNx_umap.csv', index_col=0)
# keep the cells present in the filtered Seurat object
cells = list(X_umap.index)
adata = adata[cells]
# write the Umap coordinates in obsm table (contains dimension reduction) in adata object
adata.obsm['X_umap'] = copy.deepcopy(X_umap.loc[adata.obs_names].values)

# read metadata
m = pd.read_csv("HxNx_meta.csv", index_col='Unnamed: 0')
# write the clusters id in obs table (contains meta data) in adata object
adata.obs['simplified_clusters'] = copy.deepcopy(m['simplified_clusters'].loc[adata.obs_names].values)
adata.obs['full_clusters'] = copy.deepcopy(m['full_clusters'].loc[adata.obs_names].values)

# %% [markdown]
# You can visualize the spliced/unspliced proportions, to verify that both are well loaded, and out of curiosity too.

# %%
adata.obs['simplified_clusters'] = adata.obs['simplified_clusters'].astype('category')
scv.pl.proportions(adata, groupby='simplified_clusters')

# %%
adata._X
# Out:
# <9882x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 39533409 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Preprocessing the Data
# Preprocessing consist of gene selection by minimum counts, normalizing every cell by its total size, gene selection by dispersion and logarithmizing X (assay RNA in Seurat). All these steps are ran when running `scv.pp.filter_and_normalize`. Analysis further require first and second order moments (means and uncenterd variance) among nearest neighbors in PCA space. You can change the parameters as you want, here are the default values. Note that the more cells you have, the more you can increase `n_neighbors`. If you only have very few cells, you might want to reduce this parameter. You can also change the number of top genes to keep, but the more genes, the longer the velocity recovery will take.

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 18778 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:24) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %% [markdown]
# ## Estimate RNA velocity

# %% [markdown]
# ### Dynamical method
# The dynamical method requires another step, which learn the full transcriptional dynamics of splicing kinetics. It takes much longer than the Stochastic methods, but is the most precise of all. On 11 000 cells and 2 000 genes it takes more than an hour to retrieve the full splicing kinetics, without parallelization.

# %%
scv.tl.recover_dynamics(adata) # the most time consuming step

scv.tl.velocity(adata, mode='dynamical')
scv.tl.velocity_graph(adata)
# Out:
# recovering dynamics (using 1/40 cores)
# ...
#     finished (0:27:48) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# computing velocities
#     finished (0:00:13) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:18) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %% [markdown]
# ### Visualize the velocity
# There are 3 plotting methods to visualize the velocity on a UMAP. The grid, the stream and the base (my personnal favorite is the stream, but the base one might be better for a small number of cells). There are many grahical parameters that can be changed, see the [documentation](https://scvelo.readthedocs.io/api.html) for more info

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='simplified_clusters')
scv.pl.velocity_embedding_stream(adata, basis='umap', color='simplified_clusters')
scv.pl.velocity_embedding(adata, arrow_length=4, arrow_size=4, dpi=120, color='simplified_clusters')
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding_grid(adata, basis='umap', color='full_clusters')
scv.pl.velocity_embedding_stream(adata, basis='umap', color='full_clusters')
scv.pl.velocity_embedding(adata, arrow_length=4, arrow_size=4, dpi=120, color='full_clusters')

# %%
pickle.dump(adata, open('./HxNx_dynamical.dp', 'wb'))

# %% [markdown]
# ## Velocity of Hx2

# %%
# export Seurat object information from Rstudio
Idents(HxNx) <- 'condition'
Hx <- subset(HxNx, idents='Hx2')

saveRDS(Hx, 'Hx.rds')
write.csv(x = Hx@meta.data, file = 'Hx_meta.csv')
write.csv(x = Hx@reductions$umap@cell.embeddings, file = 'Hx_umap.csv')

# %%
Hx = adata1

# read umap coordinates
X_umap = scv.load('Hx_umap.csv', index_col=0)
# keep the cells present in the filtered Seurat object
cells = list(X_umap.index)
Hx = Hx[cells]
# write the Umap coordinates in obsm table (contains dimension reduction) in adata object
Hx.obsm['X_umap'] = copy.deepcopy(X_umap.loc[Hx.obs_names].values)

# read metadata
m = pd.read_csv("Hx_meta.csv", index_col='Unnamed: 0')
# write the clusters id in obs table (contains meta data) in adata object
Hx.obs['simplified_clusters'] = copy.deepcopy(m['simplified_clusters'].loc[Hx.obs_names].values)
Hx.obs['full_clusters'] = copy.deepcopy(m['full_clusters'].loc[Hx.obs_names].values)

# %%
scv.pp.filter_and_normalize(Hx, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(Hx, n_pcs=30, n_neighbors=30)

scv.tl.recover_dynamics(Hx) # the most time consuming step

scv.tl.velocity(Hx, mode='dynamical')
scv.tl.velocity_graph(Hx)
# Out:
# Filtered out 19716 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:01) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# recovering dynamics (using 1/40 cores)
# ...
#     finished (0:18:08) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# computing velocities
#     finished (0:00:07) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:22) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_grid(Hx, basis='umap', color='full_clusters')
scv.pl.velocity_embedding_stream(Hx, basis='umap', color='full_clusters')
scv.pl.velocity_embedding(Hx, arrow_length=4, arrow_size=4, dpi=120, color='full_clusters')
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
pickle.dump(Hx, open('./Hx_dynamical.dp', 'wb'))

# %% [markdown]
# ## Velocity of Nx2

# %%
Nx = adata2

# read umap coordinates
X_umap = scv.load('Nx_umap.csv', index_col=0)
# keep the cells present in the filtered Seurat object
cells = list(X_umap.index)
Nx = Nx[cells]
# write the Umap coordinates in obsm table (contains dimension reduction) in adata object
Nx.obsm['X_umap'] = copy.deepcopy(X_umap.loc[Nx.obs_names].values)

# read metadata
m = pd.read_csv("Nx_meta.csv", index_col='Unnamed: 0')
# write the clusters id in obs table (contains meta data) in adata object
Nx.obs['simplified_clusters'] = copy.deepcopy(m['simplified_clusters'].loc[Nx.obs_names].values)
Nx.obs['full_clusters'] = copy.deepcopy(m['full_clusters'].loc[Nx.obs_names].values)

# %%
scv.pp.filter_and_normalize(Nx, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(Nx, n_pcs=30, n_neighbors=30)

scv.tl.recover_dynamics(Nx) # the most time consuming step

scv.tl.velocity(Nx, mode='dynamical')
scv.tl.velocity_graph(Nx)
# Out:
# Filtered out 19983 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# recovering dynamics (using 1/40 cores)
# ...
#     finished (0:14:49) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# computing velocities
#     finished (0:00:06) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:15) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding_grid(Nx, basis='umap', color='full_clusters')
scv.pl.velocity_embedding_stream(Nx, basis='umap', color='full_clusters')
scv.pl.velocity_embedding(Nx, arrow_length=4, arrow_size=4, dpi=120, color='full_clusters')
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
pickle.dump(Nx, open('./Nx_dynamical.dp', 'wb'))
